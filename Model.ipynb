# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
da=pd.read_csv("data.csv")
da
# Out:
#     Dep  Indep
# 0     2      4
# 1     3      9
# 2     4     16
# 3     5     25
# 4     6     36
# 5     7     49
# 6     8     64
# 7     9     81
# 8    10    100
# 9    11    121
# 10   12    144

# %%
lm=linear_model.LinearRegression()
lm.fit(da[["Dep"]],da.Indep)
# Out:
# LinearRegression()

# %%
plt.plot(da.Dep,da.Indep)

# %%
x=lm.predict(da[["Dep"]])
plt.plot(x,da.Dep)

# %%
print("The Intercept of this model is:",lm.intercept_)
print("The Slop of this model is:",lm.coef_)
# Out:
# The Intercept of this model is: -39.00000000000006
# The Slop of this model is: [14.]

# %%
x=int(input("Enter the value of the dependent variable:"))
print("The Predicted value is :",lm.predict([[x]]))
# Out:
# The Predicted value is : [311.]
# c:\Users\Brijesh AH\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import joblib
joblib.dump(lm, "model.pkl")
# Out:
# ['model.pkl']
